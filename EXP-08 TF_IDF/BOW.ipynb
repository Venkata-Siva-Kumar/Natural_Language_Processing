# %%
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense,TextVectorization

text=np.array(["I like Java", "She dislikes AI", "He loves DAA", "AI is boring"])
label=np.array([1,0,1,0])

vector= TextVectorization(output_mode="count")
vector.adapt(text)

model = Sequential([vector, Dense(16, activation="relu"), Dense(1,activation="sigmoid")])
model.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])
model.fit(tf.constant(text, dtype=tf.string), label, epochs=20)

testData = np.array(["I like DAA"],dtype=object)
predScore=model.predict(testData)
print("Accuracy Scores", predScore)

if predScore > 0.5:
  print("Label : 1")
else:
  print("Label : 0")

testSent=np.array(["He likes NLP", "She dislikes AI"],dtype=object)
predTestData=model.predict(testSent)
print("Accuracy Scores", predTestData)
for t,p in zip(testSent, predTestData):
  if p>0.5:
    print("Label : 1")
  else:
    print("Label : 0")
# Out:
# Epoch 1/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.7500 - loss: 0.5771
# Epoch 2/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7500 - loss: 0.5721
# Epoch 3/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7500 - loss: 0.5671
# Epoch 4/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7500 - loss: 0.5622
# Epoch 5/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7500 - loss: 0.5573
# Epoch 6/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.7500 - loss: 0.5525
# Epoch 7/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7500 - loss: 0.5477
# Epoch 8/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7500 - loss: 0.5430
# Epoch 9/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7500 - loss: 0.5383
# Epoch 10/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7500 - loss: 0.5336
# Epoch 11/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7500 - loss: 0.5290
# Epoch 12/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7500 - loss: 0.5244
# Epoch 13/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.5200
# Epoch 14/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.5156
# Epoch 15/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.5114
# Epoch 16/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.5072
# Epoch 17/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.5031
# Epoch 18/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.4989
# Epoch 19/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.4948
# Epoch 20/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.4908
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# Accuracy Scores [[0.60867476]]
# Label : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# Accuracy Scores [[0.6171043 ]
#  [0.31927344]]
# Label : 1
# Label : 0
