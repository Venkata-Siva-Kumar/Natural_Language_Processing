# %%
import math
from nltk.tokenize import word_tokenize
from nltk import bigrams

# %%
with open("file.txt",'r') as f:
    corpus = f.read()
print(corpus)
# Out:
# Children eat the cake with a spoon
# Children eat the cake
# Children eat the cake with iceing
# Children eat the cake with sweet
# Children eat the cake with their hand
# children eat with cake
# with eat sweet
# my friends with eat

# %%
tokens = word_tokenize(corpus.lower())

# %%
print(tokens)
# Out:
# ['children', 'eat', 'the', 'cake', 'with', 'a', 'spoon', 'children', 'eat', 'the', 'cake', 'children', 'eat', 'the', 'cake', 'with', 'iceing', 'children', 'eat', 'the', 'cake', 'with', 'sweet', 'children', 'eat', 'the', 'cake', 'with', 'their', 'hand', 'children', 'eat', 'with', 'cake', 'with', 'eat', 'sweet', 'my', 'friends', 'with', 'eat']

# %%
elem_count = {}
for element in tokens:
    elem_count[element] = elem_count.get(element,0)+1

# %%
print(elem_count)
# Out:
# {'children': 6, 'eat': 8, 'the': 5, 'cake': 6, 'with': 7, 'a': 1, 'spoon': 1, 'iceing': 1, 'sweet': 2, 'their': 1, 'hand': 1, 'my': 1, 'friends': 1}

# %%
bi_grams = list(bigrams(tokens))

# %%
bigram_count = {}
for bigram in bi_grams:
    bigram_count[bigram] = bigram_count.get(bigram,0)+1
print(bigram_count)
# Out:
# {('children', 'eat'): 6, ('eat', 'the'): 5, ('the', 'cake'): 5, ('cake', 'with'): 5, ('with', 'a'): 1, ('a', 'spoon'): 1, ('spoon', 'children'): 1, ('cake', 'children'): 1, ('with', 'iceing'): 1, ('iceing', 'children'): 1, ('with', 'sweet'): 1, ('sweet', 'children'): 1, ('with', 'their'): 1, ('their', 'hand'): 1, ('hand', 'children'): 1, ('eat', 'with'): 1, ('with', 'cake'): 1, ('with', 'eat'): 2, ('eat', 'sweet'): 1, ('sweet', 'my'): 1, ('my', 'friends'): 1, ('friends', 'with'): 1}

# %%
noun = input("Enter the Noun : ")
verb = input("Enter the Verb : ")
prep = input("Enter the Preposition : ")
# Out:
# Enter the Noun : cake
# Enter the Verb : eat
# Enter the Preposition : with

# %%
n = elem_count.get(noun,0)
v = elem_count.get(verb,0)
p_n =bigram_count.get((noun,prep),0)
p_v =bigram_count.get((verb,prep),0)
n,v,p_n,p_v
# Out:
# (6, 8, 1, 2)

# %%
def cal_prob(p_v,p_n,v,n):
    prob_v = p_v/v if v>0 else 0
    prob_n = p_n/n if n>0 else 0
    return prob_v,prob_n

# %%
prob_v,prob_n = cal_prob(p_v,p_n,v,n)

# %%
def cal_lam(prob_v,prob_n):
    lamb = math.log((prob_v*(1-prob_n))/prob_n , 2)
    return lamb

# %%
lamda = cal_lam(prob_v,prob_n)
lamda
# Out:
# 0.3219280948873626

# %%
if lamda >0:
    print("The Preposition is attached with Verb")
elif lamda<0:
    print("The Preposition is attached with Noun")
else:
    print("The Preposition attached cannot be determined")
# Out:
# The Preposition is attached with Verb
